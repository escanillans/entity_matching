# %% [markdown]
# # Project Stage 3: Blocking Step
#
# Problem Description:
# We have extracted two tables A, B. Both tables have the same schema. Now we need to perform entity matching and will do so with Magellan, an EM tool to match the two tables. The first step is to perform blocking in order to reduce the number of potential matches considered by a classifier.

# %%
import py_entitymatching as em
import pandas as pd
import os, sys
import numpy as np

# %% [markdown]
# # Read CSV
#
# - Read csv file from disk as a table and set its metadata

# %%
metacriticData = pd.read_csv('data/metacritic.csv')
wikiData = pd.read_csv('data/wikiData.csv')

# %%
# add ID column to each dataset
metacriticID = ["a" + str(num) for num in np.arange(1, len(metacriticData.index)+1)]
wikiID = ["b" + str(num) for num in np.arange(1, len(wikiData.index)+1)]

col_idx = 0
metacriticData.insert(loc = col_idx, column = 'ID', value = metacriticID)
wikiData.insert(loc = col_idx, column = 'ID', value = wikiID)

# %%
metacriticData.head()
# Out:
#    ID                       Album                       Artist  \
# 0  a1             Wrong Creatures  Black Rebel Motorcycle Club
# 1  a2           No Cross No Crown      Corrosion of Conformity
# 2  a3                      Encore                Anderson East
# 3  a4  A Day With The Homies [EP]                   Panda Bear
# 4  a5                 Four Stones                  Dean McPhee
#
#                    Genre                  Label  Producer Release Date  \
# 0           ['Pop/Rock']    ['Vagrant Records']       NaN  Jan 12 2018
# 1           ['Pop/Rock']      ['Nuclear Blast']       NaN  Jan 12 2018
# 2  ['Singer-Songwriter']  ['Low Country Sound']       NaN  Jan 12 2018
# 3           ['Pop/Rock']             ['Domino']       NaN  Jan 12 2018
# 4        ['Alternative']         ['Hood Faire']       NaN  Jan 12 2018
#
#    Meta Score
# 0          69
# 1          77
# 2          74
# 3          74
# 4          84

# %%
wikiData.head()
# Out:
#    ID                                            Album            Artist  \
# 0  b1                                          Be Calm         Air Dubai
# 1  b2                               From Parts Unknown  Every Time I Die
# 2  b3  I'm Almost Happy Here, But I Never Feel At Home       Hotel Books
# 3  b4                                            Paula      Robin Thicke
# 4  b5                             Isolate and Medicate           Seether
#
#                                                            Genre  \
# 0                                            ['Hip hop', ' pop']
# 1  ['Metalcore', ' hardcore punk', ' mathcore', ' sludge metal']
# 2                         ['Spoken word', ' indie rock', ' emo']
# 3                                                        ['R&B']
# 4            ['Post-grunge', ' hard rock', ' alternative metal']
#
#                                                              Label  \
# 0                                                     ['Hopeless']
# 1                                                      ['Epitaph']
# 2                                                      ['inVogue']
# 3                                     ['Star Trak', ' Interscope']
# 4  ['The Bicycle Music Company', ' Concord Bicycle', ' Spinefarm']
#
#                                Producer Release Date  Meta Score
# 0  ['Dwight A. Baker', ' Colin Munroe']   Jul 1 2014         NaN
# 1                       ['Kurt Ballou']   Jul 1 2014         NaN
# 2      ['Jay Maas', ' Hiram Hernandez']   Jul 1 2014         NaN
# 3          ['Robin Thicke', ' Pro Jay']   Jul 1 2014         NaN
# 4                   ["Brendan O'Brien"]   Jul 1 2014         NaN

# %%
# set metadata
em.set_key(wikiData, 'ID')
em.set_key(metacriticData, 'ID')

#set albums and artists to lower case
wikiData["Album"] = wikiData["Album"].str.lower()
metacriticData["Album"] = metacriticData["Album"].str.lower()

wikiData["Artist"] = wikiData["Artist"].str.lower()
metacriticData["Artist"] = metacriticData["Artist"].str.lower()

#preprocessing -- set all months to have only 3 letters so dates match
def shorten_month(x):
    month, day, year = x.split(" ")
    month = month[0:3]
    return " ".join([month,day,year])
wikiData["Release Date"] = wikiData["Release Date"].apply(shorten_month)
metacriticData["Release Date"] = metacriticData["Release Date"].apply(shorten_month)

# %% [markdown]
# # Blocking
# We will union the results of 4 blockers to get a final set of candidates.
# 1. Attribute equivalence on album title
# 2. Attribute equivalence on artist
# 3. Attribute equivalence on release date and at least 2 word overlap on album title
# 4. Attribute equivalence on release date and at least 1 word overlap on artist

# %%
#1. block with album title
ab1 = em.AttrEquivalenceBlocker()
C1 = ab1.block_tables(metacriticData, wikiData, 
                   l_block_attr='Album', r_block_attr='Album', 
                    l_output_attrs=['Album', 'Artist', 'Release Date'],
                    r_output_attrs=['Album', 'Artist', 'Release Date'])

print len(C1)
C1.head(5)
# Out:
# 1034
#    _id ltable_ID rtable_ID    ltable_Album  ltable_Artist ltable_Release Date  \
# 0    0        a3     b1611          encore  anderson east         Jan 12 2018
# 1    1     a1783     b1611          encore       dj snake          Aug 5 2016
# 2    2        a9      b746      underworld  tonight alive         Jan 12 2018
# 3    3       a16     b3181  saturation iii   brockhampton         Dec 15 2017
# 4    4       a18      b933         revival         eminem         Dec 15 2017
#
#      rtable_Album rtable_Artist rtable_Release Date
# 0          encore      dj snake          Aug 5 2016
# 1          encore      dj snake          Aug 5 2016
# 2      underworld    symphony x         Jul 24 2015
# 3  saturation iii  brockhampton         Dec 15 2017
# 4         revival  selena gomez          Oct 9 2015

# %%
#2. block with artist name
ab2 = em.AttrEquivalenceBlocker()
C2 = ab2.block_tables(metacriticData, wikiData, 
                   l_block_attr='Artist', r_block_attr='Artist', 
                    l_output_attrs=['Album', 'Artist', 'Release Date'],
                    r_output_attrs=['Album', 'Artist', 'Release Date'],
                    allow_missing=True)
print len(C2)
C2.head(5)
# Out:
# 2100
#    _id ltable_ID rtable_ID                ltable_Album      ltable_Artist  \
# 0    0        a4      b359  a day with the homies [ep]         panda bear
# 1    1        a8      b249                        vale  black veil brides
# 2    2        a9     b1263                  underworld      tonight alive
# 3    3     a2369     b1263                   limitless      tonight alive
# 4    4       a11      b938                blue madonna              bØrns
#
#   ltable_Release Date                      rtable_Album      rtable_Artist  \
# 0         Jan 12 2018  panda bear meets the grim reaper         panda bear
# 1         Jan 12 2018                 black veil brides  black veil brides
# 2         Jan 12 2018                         limitless      tonight alive
# 3          Mar 4 2016                         limitless      tonight alive
# 4         Jan 12 2018                          dopamine              bØrns
#
#   rtable_Release Date
# 0         Jan 13 2015
# 1         Oct 27 2014
# 2          Mar 4 2016
# 3          Mar 4 2016
# 4         Oct 16 2015

# %%
#3. Overlap
#3.1 overlap at least 2 words of album title
ob3 = em.OverlapBlocker()
C3 = ob3.block_tables(metacriticData, wikiData,'Album','Album',word_level=True,overlap_size=2,
                   l_output_attrs=["Album","Artist","Release Date"],
                   r_output_attrs=["Album","Artist","Release Date"],
                    show_progress=False)

#3.2. same release date
a3 = em.AttrEquivalenceBlocker()
C3 = a3.block_candset(C3, 'Release Date', 'Release Date',show_progress=False)
print(len(C3))
# Out:
# 812

# %%
#4. Overlap
#4.1 overlap at least 1 words of artist
ob4 = em.OverlapBlocker()
C4 = ob4.block_tables(metacriticData, wikiData,'Artist','Artist',word_level=True,overlap_size=1,
                   l_output_attrs=["Album","Artist","Release Date"],
                   r_output_attrs=["Album","Artist","Release Date"],
                    show_progress=False)

#4.2. same release date
a4 = em.AttrEquivalenceBlocker()
C4 = a4.block_candset(C4, 'Release Date', 'Release Date',show_progress=False)
print(len(C4))
# Out:
# 1595

# %% [markdown]
# ### Union results together to get final candidate set

# %%
G = em.combine_blocker_outputs_via_union([C1, C2, C3, C4])
print len(G)

G.head(10)
# Out:
# 3006
#    _id ltable_ID rtable_ID                                  ltable_Album  \
# 0    0     a1001     b2328                      black and white rainbows
# 1    1     a1001      b238                      black and white rainbows
# 2    2     a1004     b2330                           different creatures
# 3    3     a1004      b494                           different creatures
# 4    4     a1005     b2355  jawbone [original motion picture soundtrack]
# 5    5     a1005     b2675  jawbone [original motion picture soundtrack]
# 6    6     a1009     b2350                                      elektrac
# 7    7     a1010     b2358                                         packs
# 8    8     a1010      b324                                         packs
# 9    9     a1012     b2346                            captain california
#
#      ltable_Artist ltable_Release Date  \
# 0             bush         Mar 10 2017
# 1             bush         Mar 10 2017
# 2      circa waves         Mar 10 2017
# 3      circa waves         Mar 10 2017
# 4      paul weller         Mar 10 2017
# 5      paul weller         Mar 10 2017
# 6  shobaleader one         Mar 10 2017
# 7   your old droog         Mar 10 2017
# 8   your old droog         Mar 10 2017
# 9             murs         Mar 10 2017
#
#                                                rtable_Album    rtable_Artist  \
# 0                                  black and white rainbows             bush
# 1                                            man on the run             bush
# 2                                       different creatures      circa waves
# 3                                             young chasers      circa waves
# 4  beauty and the beast: original motion picture soundtrack  various artists
# 5                                         a kind revolution      paul weller
# 6                                                  elektrac  shobaleader one
# 7                                                     packs   your old droog
# 8                                            your old droog   your old droog
# 9                                        captain california             murs
#
#   rtable_Release Date
# 0         Mar 10 2017
# 1         Oct 21 2014
# 2         Mar 10 2017
# 3         Mar 30 2015
# 4         Mar 10 2017
# 5         May 12 2017
# 6         Mar 10 2017
# 7         Mar 10 2017
# 8         Nov 25 2014
# 9         Mar 10 2017

# %% [markdown]
# ### Run debugger to make sure not missing any valid matches

# %%
dbg = em.debug_blocker(G,metacriticData,wikiData,output_size=50)
dbg
# Out:
#     _id ltable_ID rtable_ID                          ltable_Album  \
# 0     0      a698     b2713                     a  world of masks
# 1     1     a2144     b1976                prayers for the damned
# 2     2     a1746     b2964                        a  weird exits
# 3     3     a1822     b2819                        vulnicura live
# 4     4     a1768      b101                              blossoms
# 5     5     a1790      b254                       for all we know
# 6     6     a1804     b1765                 live in san francisco
# 7     7     a1804     b2964                 live in san francisco
# 8     8     a1809      b532                       born of the sun
# 9     9     a1814     b1131                              redshift
# 10   10     a1817     b1957                     everybody looking
# 11   11     a1875     b2612               the  mountain will fall
# 12   12     a1824     b1129                           love & hate
# 13   13     a1826     b3063                           loud hailer
# 14   14     a1839     b1574                            wildflower
# 15   15     a1848      b268                       black bubblegum
# 16   16     a1854     b2543                            day to day
# 17   17     a1857     b2441                      beautiful broken
# 18   18     a1861       b52                             the bride
# 19   19     a1861     b1529                             the bride
# 20   20     a1872      b569                             the magic
# 21   21     a1880      b738                      life in the dark
# 22   22     a1667      b997                                 ultra
# 23   23     a1627     b1702                                   aim
# 24   24     a1628     b1702                              schmilco
# 25   25     a1644      b252                         transcendence
# 26   26     a1644     b2961                         transcendence
# 27   27     a1654     b1284  philosophy of the world [remastered]
# 28   28     a1657     b1703                              stripped
# 29   29     a1662     b1396       birds in the trap sing mcknight
# 30   30     a1665      b101                                 trick
# 31   31     a1763     b1715        give a glimpse of what yer not
# 32   32     a1704     b2260             the  sides and in between
# 33   33     a1721      b145                                callus
# 34   34     a1721      b673                                callus
# 35   35     a1721      b882                                callus
# 36   36     a1721     b1634                                callus
# 37   37     a1721     b1639                                callus
# 38   38     a1731     b2393                   the  hanging valley
# 39   39     a1735     b2311                      of monkees & men
# 40   40     a2032     b1464         stranger things have happened
# 41   41     a2008      b135                              the ride
# 42   42     a2008      b212                              the ride
# 43   43     a2015     b3038                                27-jul
# 44   44     a2020     b2543               the yard work simulator
# 45   45     a2021     b1474                          folding time
# 46   46     a2022     b1474                                 tempo
# 47   47     a2022     b3154                                 tempo
# 48   48     a2024     b1474                              dj-kicks
# 49   49     a2027     b1474                          transmission
#
#               ltable_Artist    ltable_Genre                    ltable_Label  \
# 0         the heliocentrics  ['Electronic']                    ['Soundway']
# 1                sixx: a.m.    ['Pop/Rock']                ['Eleven Seven']
# 2              thee oh sees    ['Pop/Rock']                 ['Castle Face']
# 3                     björk  ['Electronic']           ['One Little Indian']
# 4                  blossoms    ['Pop/Rock']                  ['Virgin EMI']
# 5                       nao         ['R&B']                         ['RCA']
# 6              thee oh sees    ['Pop/Rock']                 ['Castle Face']
# 7              thee oh sees    ['Pop/Rock']                 ['Castle Face']
# 8               faun fables        ['Folk']                   ['Drag City']
# 9                    rhyton    ['Pop/Rock']               ['Thrill Jockey']
# 10               gucci mane         ['Rap']                    ['Atlantic']
# 11                dj shadow  ['Electronic']                 ['Mass Appeal']
# 12         michael kiwanuka         ['R&B']                  ['Interscope']
# 13                jeff beck    ['Pop/Rock']                       ['Rhino']
# 14           the avalanches  ['Electronic']                 ['Astralwerks']
# 15            eric copeland    ['Pop/Rock']                         ['DFA']
# 16           sarathy korwar  ['Electronic']                  ['Ninja Tune']
# 17                    heart    ['Pop/Rock']                     ['Concord']
# 18           bat for lashes    ['Pop/Rock']                ['Warner Bros.']
# 19           bat for lashes    ['Pop/Rock']                ['Warner Bros.']
# 20                 deerhoof    ['Pop/Rock']                   ['Polyvinyl']
# 21      the felice brothers    ['Pop/Rock']                     ['Yep Roc']
# 22                    zomby  ['Electronic']                    ['Hyperdub']
# 23                   m.i.a.  ['Electronic']                  ['Interscope']
# 24                    wilco    ['Pop/Rock']                       ['Anti-']
# 25   devin townsend project    ['Pop/Rock']            ['Inside Out Music']
# 26   devin townsend project    ['Pop/Rock']            ['Inside Out Music']
# 27               the shaggs             NaN  ['Light in the Attic Records']
# 28                macy gray        ['Jazz']              ['Chesky Records']
# 29             travis scott         ['Rap']                        ['Epic']
# 30                 jamie t.    ['Pop/Rock']                  ['Virgin EMI']
# 31             dinosaur jr.    ['Pop/Rock']                  ['Jagjaguwar']
# 32              gringo star    ['Pop/Rock']              ['Nevado Records']
# 33                gonjasufi  ['Electronic']                        ['Warp']
# 34                gonjasufi  ['Electronic']                        ['Warp']
# 35                gonjasufi  ['Electronic']                        ['Warp']
# 36                gonjasufi  ['Electronic']                        ['Warp']
# 37                gonjasufi  ['Electronic']                        ['Warp']
# 38               cold pumas    ['Pop/Rock']              ['Gringo Records']
# 39              the minus 5    ['Pop/Rock']                     ['Yep Roc']
# 40            clare maguire    ['Pop/Rock']                  ['Virgin EMI']
# 41  catfish & the bottlemen    ['Pop/Rock']                     ['Capitol']
# 42  catfish & the bottlemen    ['Pop/Rock']                     ['Capitol']
# 43            fifth harmony         ['Pop']                        ['Epic']
# 44                max graef  ['Electronic']                  ['Ninja Tune']
# 45                sepalcure  ['Electronic']                    ['Hotflush']
# 46                olga bell  ['Electronic']           ['One Little Indian']
# 47                olga bell  ['Electronic']           ['One Little Indian']
# 48                 dâm-funk  ['Electronic']                         ['!K7']
# 49           death in vegas  ['Electronic']             ['Forced Exposure']
#
#     ltable_Producer ltable_Release Date                          rtable_Album  \
# 0               NaN         May 26 2017                    in a world of fear
# 1               NaN         Apr 29 2016               prayers for the blessed
# 2               NaN         Aug 12 2016                                   orc
# 3               NaN         Jul 22 2016  songs from the novel 'greatest hits'
# 4               NaN          Aug 5 2016                                listen
# 5               NaN         Jul 29 2016                  honor is all we know
# 6               NaN         Jul 29 2016                     live in san diego
# 7               NaN         Jul 29 2016                                   orc
# 8               NaN         Jul 22 2016                       edge of the sun
# 9               NaN         Jul 22 2016                     the catastrophist
# 10              NaN         Jul 22 2016     free bricks 2k16 (zone 6 edition)
# 11              NaN         Jun 24 2016                   the walls will fall
# 12              NaN         Jul 15 2016                    sex love & pain ii
# 13              NaN         Jul 15 2016                                colors
# 14              NaN          Jul 8 2016                        the poison red
# 15              NaN          Jul 8 2016                                 ixora
# 16              NaN          Jul 8 2016                                   azd
# 17              NaN          Jul 8 2016                              keepsake
# 18              NaN          Jul 1 2016                           the voyager
# 19              NaN          Jul 1 2016                           the getaway
# 20              NaN         Jun 24 2016                        the magic whip
# 21              NaN         Jun 24 2016                    born in the echoes
# 22              NaN          Sep 2 2016                               nothing
# 23              NaN          Sep 9 2016                                  here
# 24              NaN          Sep 9 2016                                  here
# 25              NaN          Sep 9 2016                                    z²
# 26              NaN          Sep 9 2016                                malina
# 27              NaN          Sep 9 2016          girl at the end of the world
# 28              NaN          Sep 9 2016                           atmosphères
# 29              NaN          Sep 2 2016                    everything at once
# 30              NaN          Sep 2 2016                                listen
# 31              NaN          Aug 5 2016                      together, as one
# 32              NaN         Aug 26 2016                            in between
# 33              NaN         Aug 19 2016                                  syro
# 34              NaN         Aug 19 2016                               lantern
# 35              NaN         Aug 19 2016                           foam island
# 36              NaN         Aug 19 2016                          brave enough
# 37              NaN         Aug 19 2016                                   dna
# 38              NaN         Aug 19 2016                            the valley
# 39              NaN         Aug 19 2016                                 voids
# 40              NaN         May 27 2016                    lexicon of love ii
# 41              NaN         May 27 2016                           the balcony
# 42              NaN         May 27 2016                              ride out
# 43              NaN         May 27 2016                                scream
# 44              NaN         May 27 2016                                   azd
# 45              NaN         May 27 2016                                  skin
# 46              NaN         May 27 2016                                  skin
# 47              NaN         May 27 2016                                utopia
# 48              NaN         May 27 2016                                  skin
# 49              NaN         May 27 2016                                  skin
#
#                                                    rtable_Artist  \
# 0                                               scale the summit
# 1                                                      sixx:a.m.
# 2                                                        oh sees
# 3                                               kathryn williams
# 4                                                      the kooks
# 5                                                         rancid
# 6                                                   eric clapton
# 7                                                        oh sees
# 8                                                       calexico
# 9                                                       tortoise
# 10                                         gucci mane and future
# 11                                                        terror
# 12                                                          tank
# 13                                                          beck
# 14                                                      nonpoint
# 15                                                      copeland
# 16                                                       actress
# 17                                                   heavy heart
# 18                                                   jenny lewis
# 19                                         red hot chili peppers
# 20                                                          blur
# 21                                         the chemical brothers
# 22                                                         kode9
# 23                                               teenage fanclub
# 24                                               teenage fanclub
# 25                                                devin townsend
# 26                                                       leprous
# 27                                                         james
# 28  tigran hamasyan, arve henriksen, eivind aarset, and jan bang
# 29                                                        travis
# 30                                                     the kooks
# 31                                                      dinosaur
# 32                                                   the feelies
# 33                                                    aphex twin
# 34                                                hudson mohawke
# 35                                                      darkstar
# 36                                              lindsey stirling
# 37                                                         trapt
# 38                                                     betty who
# 39                                                minus the bear
# 40                                                           abc
# 41                                     catfish and the bottlemen
# 42                                                     bob seger
# 43                                               michael jackson
# 44                                                       actress
# 45                                                         flume
# 46                                                         flume
# 47                                                         björk
# 48                                                         flume
# 49                                                         flume
#
#                                                                                          rtable_Genre  \
# 0                                                                                                 NaN
# 1                                                                                                 NaN
# 2                                                                                                 NaN
# 3                                                                                                 NaN
# 4                                                                                      ['Indie rock']
# 5                                                                          ['Punk rock', ' ska punk']
# 6                                                                ['Rock', ' blues rock', ' pop rock']
# 7                                                                                                 NaN
# 8                 ['Alt-rock', ' indie folk', ' Americana', ' Tex-Mex', ' alt-country', ' post-rock']
# 9                                                                                       ['Post-rock']
# 10                                                                               ['Hip hop', ' trap']
# 11                                                                                  ['Hardcore punk']
# 12                                                                                            ['R&B']
# 13                                                   ['Pop rock', ' dance-rock', ' experimental pop']
# 14                                                                                                NaN
# 15                                                                 ['Alternative rock', ' indie pop']
# 16                                                                                     ['Electronic']
# 17                                                  ['Alternative rock', ' dream pop', ' shoegazing']
# 18                                                                                     ['Indie rock']
# 19                                                    ['Funk rock', ' alternative rock', ' pop rock']
# 20                                                                                        ['Britpop']
# 21                                                  ['Electronica', ' trip hop', ' house', ' techno']
# 22                                                                                     ['Electronic']
# 23                                                                               ['Alternative rock']
# 24                                                                               ['Alternative rock']
# 25  ['Progressive metal', ' industrial metal', ' progressive rock', ' experimental rock', ' new-age']
# 26                                   ['Progressive metal', ' avant-garde metal', ' progressive rock']
# 27                                                                               ['Alternative rock']
# 28                                                                                           ['Jazz']
# 29                                 ['Post-Britpop', ' alternative rock', ' indie rock', ' soft rock']
# 30                                                                                     ['Indie rock']
# 31                                                                                           ['Jazz']
# 32                                                                                           ['Rock']
# 33                                                                                     ['Electronic']
# 34                                                                                     ['Electronic']
# 35                                                                                     ['Electronic']
# 36                                                                                     ['Electronic']
# 37                                   ['Hard rock', ' alternative metal', ' post-grunge', ' nu metal']
# 38                                                                                                NaN
# 39                                           ['Math rock', ' experimental rock', ' progressive rock']
# 40                                                                                                NaN
# 41                                                                ['Indie rock', ' alternative rock']
# 42                                                                        ['Rock', ' heartland rock']
# 43                                                                                            ['Pop']
# 44                                                                                     ['Electronic']
# 45                                                                                     ['Electronic']
# 46                                                                                     ['Electronic']
# 47                                                                        ['Electronica', ' ambient']
# 48                                                                                     ['Electronic']
# 49                                                                                     ['Electronic']
#
#                       rtable_Label  \
# 0                              NaN
# 1                 ['Eleven Seven']
# 2                  ['Castle Face']
# 3            ['One Little Indian']
# 4                   ['Virgin EMI']
# 5          ['Hellcat', ' Epitaph']
# 6                      ['Reprise']
# 7                  ['Castle Face']
# 8                        ['ANTI-']
# 9                ['Thrill Jockey']
# 10                        ['1017']
# 11                  ['Pure Noise']
# 12                    ['Atlantic']
# 13                     ['Capitol']
# 14                   ['Spinefarm']
# 15                ['Tooth & Nail']
# 16                  ['Ninja Tune']
# 17      ['I Can & I Will Records']
# 18                ['Warner Bros.']
# 19                ['Warner Bros.']
# 20                  ['Parlophone']
# 21  ['Astralwerks', ' Virgin EMI']
# 22                    ['Hyperdub']
# 23                             NaN
# 24                             NaN
# 25                    ['HevyDevy']
# 26            ['Inside Out Music']
# 27                         ['BMG']
# 28                         ['ECM']
# 29           ['Red Telephone Box']
# 30                  ['Virgin EMI']
# 31                     ['Edition']
# 32            ['Bar/None Records']
# 33                        ['Warp']
# 34                        ['Warp']
# 35                        ['Warp']
# 36                ['Lindseystomp']
# 37                             NaN
# 38                         ['RCA']
# 39             ['Suicide Squeeze']
# 40                  ['Virgin EMI']
# 41  ['Island', ' Communion Music']
# 42                     ['Capitol']
# 43                        ['Epic']
# 44                  ['Ninja Tune']
# 45              ['Future Classic']
# 46              ['Future Classic']
# 47           ['One Little Indian']
# 48              ['Future Classic']
# 49              ['Future Classic']
#
#                                                                                         rtable_Producer  \
# 0                                                                                                   NaN
# 1                                                                                                   NaN
# 2                                                                                                   NaN
# 3                                                                                     ['Romeo Stodart']
# 4                                                       ['Luke Pritchard', ' Inflo', ' Fraser T Smith']
# 5                                                                                    ['Brett Gurewitz']
# 6                                                                     ['Simon Climie', ' Eric Clapton']
# 7                                                                                                   NaN
# 8                            ['Joey Burns', ' John Convertino', ' Sergio Mendoza', ' Craig Schumacher']
# 9                                                                                                   NaN
# 10                                   ['London on da Track', ' Metro Boomin', ' Southside', ' Zaytoven']
# 11                                                                                                  NaN
# 12  ['Alvin Isaacs', ' Antoinette Roberson', ' B. A. M.', ' Bryan Harrison', ' Bryan Nelson', ' Chri...
# 13                                                            ['Beck', ' Greg Kurstin', ' Cole M.G.N.']
# 14                                                                                                  NaN
# 15                                                                                      ['Aaron Marsh']
# 16                                                                                          ['Actress']
# 17                                                                                  ['Patrick Fitzroy']
# 18                                                                                       ['Ryan Adams']
# 19                                                                                     ['Danger Mouse']
# 20                                                 ['Damon Albarn', ' Graham Coxon', ' Stephen Street']
# 21                                                                            ['The Chemical Brothers']
# 22                                                                                                  NaN
# 23                                                                                                  NaN
# 24                                                                                                  NaN
# 25                                                                                   ['Devin Townsend']
# 26                                                                                                  NaN
# 27                                                                                       ['Max Dingel']
# 28                                                                                                  NaN
# 29                                                                                   ['Michael Ilbert']
# 30                                                      ['Luke Pritchard', ' Inflo', ' Fraser T Smith']
# 31                                                                                       ['Laura Jurd']
# 32                                                                                                  NaN
# 33                                                                                       ['Aphex Twin']
# 34                                                                                   ['Hudson Mohawke']
# 35                                                                                                  NaN
# 36  ['AFSHeeN', ' Andrew Goldstein', ' Gladius', ' Jason Yik Nam Wu', ' Josh Abraham', ' Keith Varon...
# 37                          ['Crash Collide Records', ' The End', ' Alternative Distribution Alliance']
# 38  ['Peter Thomas', ' Pretty Sister', ' Pop & Oak', ' Trevor Brown', ' Zaire Koalo', ' Oliver "Olig...
# 39                                                                                   ['Minus the Bear']
# 40                                                                    ['Gary Stevenson', ' Martin Fry']
# 41                                                                                       ['Jim Abbiss']
# 42                                                                                        ['Bob Seger']
# 43  ['Michael Jackson', ' Curtis Anthony Nolen', ' Rockwell', ' The Jacksons', ' Quincy Jones', ' Ja...
# 44                                                                                          ['Actress']
# 45                                                                                   ['Harley Streten']
# 46                                                                                   ['Harley Streten']
# 47                                                                         ['Björk', ' Arca', ' Rabit']
# 48                                                                                   ['Harley Streten']
# 49                                                                                   ['Harley Streten']
#
#    rtable_Release Date
# 0          May 19 2017
# 1          Nov 18 2016
# 2          Aug 25 2017
# 3          Jun 16 2017
# 4           Sep 1 2014
# 5          Oct 27 2014
# 6          Sep 30 2016
# 7          Aug 25 2017
# 8          Apr 13 2015
# 9          Jan 22 2016
# 10         Nov 14 2016
# 11         Apr 28 2017
# 12         Jan 22 2016
# 13         Oct 13 2017
# 14          Jul 8 2016
# 15         Oct 31 2014
# 16         Apr 17 2017
# 17         Mar 31 2017
# 18         Jul 29 2014
# 19         Jun 17 2016
# 20         Apr 27 2015
# 21         Jul 24 2015
# 22          Nov 6 2015
# 23          Sep 9 2016
# 24          Sep 9 2016
# 25         Oct 27 2014
# 26         Aug 25 2017
# 27         Mar 18 2016
# 28          Sep 9 2016
# 29         Apr 29 2016
# 30          Sep 1 2014
# 31         Sep 16 2016
# 32         Feb 24 2017
# 33         Sep 19 2014
# 34         Jun 16 2015
# 35         Sep 25 2015
# 36         Aug 19 2016
# 37         Aug 19 2016
# 38         Mar 24 2017
# 39          Mar 3 2017
# 40         May 27 2016
# 41         Sep 15 2014
# 42         Oct 14 2014
# 43         Sep 29 2017
# 44         Apr 17 2017
# 45         May 27 2016
# 46         May 27 2016
# 47         Nov 24 2017
# 48         May 27 2016
# 49         May 27 2016

# %% [markdown]
# ### Save dataset and set aside sample for labeling

# %%
# save data
file_name = 'candidates.csv'
G.to_csv(file_name, sep=',')

# Take sample to label
s_file_name = "candidates_sample.csv"
import os.path
if not os.path.isfile(s_file_name): #so you don't delete your labels on accident
    S = em.sample_table(G,100)
    S.to_csv(s_file_name,sep=",")
else:
    print "Sample file already exists, so not overwriting it"
